# %%
import sys
import os
sys.path.insert(0, os.path.abspath('.'))
sys.path.append('Archivos')

from graficar import ejecutar_todas_graficas

# %%
ejecutar_todas_graficas()
# Out:
# ...
# ANÁLISIS DE TIEMPOS DE EJECUCIÓN - ALGORITMOS SAT
# ...
#
# 📊 GRÁFICAS INDIVIDUALES POR ALGORITMO - REGLAS
# --------------------------------------------------
#
# ▶ SATtabla - Reglas Individuales
# ▶ SATtableaux-Profundidad - Reglas Individuales
# ▶ SATtableaux-Anchura - Reglas Individuales
# ▶ SATtableaux-Backtracking - Reglas Individuales
# ▶ DPLL - Reglas Individuales
# ▶ SATsolver - Reglas Individuales
# ▶ walkSAT - Reglas Individuales
# 📈 GRÁFICAS INDIVIDUALES POR ALGORITMO - CONJUNCIONES
# --------------------------------------------------
#
# ▶ SATtableaux-Profundidad - Conjunciones
# ▶ SATtableaux-Anchura - Conjunciones
# ▶ SATtableaux-Backtracking - Conjunciones
# ▶ DPLL - Conjunciones
# ▶ SATsolver - Conjunciones
# ▶ walkSAT - Conjunciones
# 🔍 GRÁFICAS COMPARATIVAS
# --------------------------------------------------
#
# ▶ Comparativa General - Reglas Individuales
# ▶ Comparativa General - Conjunciones
# ...
# ¡ANÁLISIS COMPLETADO!
# ...
